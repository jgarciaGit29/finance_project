# %%
import pandas as pd
df_raw = pd.read_csv(r'data/raw/Tesla_Historical_data.csv')

# %%
df_raw
# Out:
#                            Date        Open        High         Low  \
# 0     2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333
# 1     2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333
# 2     2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333
# 3     2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333
# 4     2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333
# ...                         ...         ...         ...         ...
# 3522  2024-06-27 00:00:00-04:00  195.169998  198.720001  194.050003
# 3523  2024-06-28 00:00:00-04:00  199.550003  203.199997  195.259995
# 3524  2024-07-01 00:00:00-04:00  201.020004  213.229996  200.850006
# 3525  2024-07-02 00:00:00-04:00  218.889999  231.300003  218.059998
# 3526  2024-07-03 00:00:00-04:00  234.559998  248.350006  234.250000
#
#            Close     Volume  Dividends  Stock Splits
# 0       1.592667  281494500        0.0           0.0
# ...

# %%
df_tesla_raw = df_raw

# %%
df_tesla_raw.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3527.000000  3527.000000  3527.000000  3527.000000  3.527000e+03
# mean     74.645840    76.275151    72.907473    74.632339  9.681977e+07
# std     102.076117   104.332901    99.613645   102.009293  7.879438e+07
# min       1.076000     1.108667     0.998667     1.053333  1.777500e+06
# 25%      11.418000    11.704667    11.126333    11.471334  4.746555e+07
# 50%      17.378668    17.628668    17.048668    17.381332  8.203590e+07
# 75%     153.415001   159.004997   148.908333   153.758331  1.225988e+08
# max     411.470001   414.496674   405.666656   409.970001  9.140820e+08
#
#        Dividends  Stock Splits
# count     3527.0   3527.000000
# mean         0.0      0.002268
# std          0.0      0.098171
# min          0.0      0.000000
# 25%          0.0      0.000000
# 50%          0.0      0.000000
# 75%          0.0      0.000000
# max          0.0      5.000000

# %%
# Check for NUlls
df_tesla_raw.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
df_tesla_raw.to_csv(r'data/cleaned/Tesla_Historical_Data.csv')

# %%
df_tesla_processed = pd.read_csv(r'data/cleaned/Tesla_Historical_Data.csv')

# %%
#Display Telsa Closing Price Over Time.
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
plt.plot(df_tesla_processed.index,df_tesla_processed['Close'], label='Close Price')
plt.title('Telsa Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Date')
plt.legend()
plt.show()

# %% [markdown]
# # Clean up data further.

# %%
# Drop the unnecessary 'Unnamed: 0' column
df_tesla_processed_clean = df_tesla_processed.drop(columns=['Unnamed: 0'])
# Convert the 'Date' column to datetime to ensure proper date-time handling
df_tesla_processed['Date'] = pd.to_datetime(df_tesla_processed['Date'])
# Convert numeric columns to appropriate data types
numeric_cols = ['Open','High','Low','Close','Volume','Dividens','Stock Splits']
df_tesla_processed[numeric_cols] = df_tesla_processed[numeric_cols].apply(pd.to_numeric, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       2 df_tesla_processed_clean = df_tesla_processed.drop(columns=['Unnamed: 0'])
#       3 # Convert the 'Date' column to datetime to ensure proper date-time handling
# ----> 4 df_tesla_processed['Date'] = pd.to_datetime(df_tesla_processed['Date'])
#
# File ~/finance_project/finance_project_env/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...
